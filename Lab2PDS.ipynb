# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A510E6/23CSBTB29/blob/main/Lab2PDS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

temps = np.array([15, 17, 20, 25, 30, 35, 33, 31, 28, 22, 18, 16])
months = np.array(["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"])

avg_temp = np.mean(temps)
hottest_month = months[np.argmax(temps)]
coldest_month = months[np.argmin(temps)]
norm_temps = (temps - temps.min()) / (temps.max() - temps.min())
above_avg_months = months[temps > avg_temp]
temps_f = temps * 9/5 + 32

print("Average Temperature (°C):", round(avg_temp, 2))
print("Hottest Month:", hottest_month, "(", temps[np.argmax(temps)], "°C )")
print("Coldest Month:", coldest_month, "(", temps[np.argmin(temps)], "°C )")
print("\nNormalized Temperatures (0-1 scale):")
print(norm_temps)
print("\nMonths above average temperature:", above_avg_months)
print("\nTemperatures in Fahrenheit:")
print(temps_f)
# Out:
# Average Temperature (°C): 24.17
# Hottest Month: Jun ( 35 °C )
# Coldest Month: Jan ( 15 °C )
#
# Normalized Temperatures (0-1 scale):
# [0.   0.1  0.25 0.5  0.75 1.   0.9  0.8  0.65 0.35 0.15 0.05]
#
# Months above average temperature: ['Apr' 'May' 'Jun' 'Jul' 'Aug' 'Sep']
#
# Temperatures in Fahrenheit:
# [59.  62.6 68.  77.  86.  95.  91.4 87.8 82.4 71.6 64.4 60.8]

# %%
import pandas as pd

data = {
    "OrderID": [101, 102, 103, 104, 105],
    "Product": ["Laptop", "Phone", "Tablet", "Laptop", "Phone"],
    "Quantity": [2, 5, 3, 1, 10],
    "Price": [50000, 15000, 20000, 50000, 15000]
}

df = pd.DataFrame(data)
df["TotalSale"] = df["Quantity"] * df["Price"]
high_sales = df[df["TotalSale"] > 1000]
most_sold = df.groupby("Product")["Quantity"].sum().idxmax()
df["Discount"] = df["TotalSale"].apply(lambda x: x * 0.1 if x > 40000 else x * 0.05)

summary = df.groupby("Product").agg({"Quantity": "sum", "TotalSale": "sum", "Discount": "sum"})
summary.to_excel("sales_summary.xlsx")

print("Full Data:\n", df)
print("\nOrders with Total Sale > 1000:\n", high_sales)
print("\nMost Sold Product:", most_sold)
print("\nSales Summary:\n", summary)
# Out:
# Full Data:
#     OrderID Product  Quantity  Price  TotalSale  Discount
# 0      101  Laptop         2  50000     100000   10000.0
# 1      102   Phone         5  15000      75000    7500.0
# 2      103  Tablet         3  20000      60000    6000.0
# 3      104  Laptop         1  50000      50000    5000.0
# 4      105   Phone        10  15000     150000   15000.0
#
# Orders with Total Sale > 1000:
#     OrderID Product  Quantity  Price  TotalSale
# 0      101  Laptop         2  50000     100000
# 1      102   Phone         5  15000      75000
# 2      103  Tablet         3  20000      60000
# 3      104  Laptop         1  50000      50000
# 4      105   Phone        10  15000     150000
#
# Most Sold Product: Phone
#
# Sales Summary:
#           Quantity  TotalSale  Discount
# Product
# Laptop          3     150000   15000.0
# Phone          15     225000   22500.0
# Tablet          3      60000    6000.0
